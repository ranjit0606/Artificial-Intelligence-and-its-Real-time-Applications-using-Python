# %%
# %pip install -U spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    --------------------------- ------------ 9.7/14.2 MB 45.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 37.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/653.1 kB ? eta -:--:--
#    ---------------------------------------- 653.1/653.1 kB 24.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 30.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 6.2/6.2 MB 39.9 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/18 [wasabi]
#    -- -------------------------------------  1/18 [spacy-loggers]
#    -- -------------------------------------  1/18 [spacy-loggers]
# ...

# %%
# !python -m spacy download en
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------- ----------------------------- 3.4/12.8 MB 33.2 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 31.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 24.7 MB/s  0:00:00
# ...
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use
# the full pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
#create a doc object
doc=nlp(u'tesla is looking at buying u,s startup for $6million')
#print each token sepeartely
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# tesla PROPN nsubj
# is AUX aux
# looking VERB ccomp
# at ADP prep
# buying VERB pcomp
# u NOUN dobj
# , PUNCT punct
# s AUX aux
# startup VERB ROOT
# for ADP prep
# $ SYM nmod
# 6million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x2cf5df18770>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x2cf5df18530>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x2cf5d99a500>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x2cf5dc848d0>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x2cf5d925e10>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x2cf5d99a110>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2=nlp(u"tesla isn't  looking into startups anymore")

for token in doc2:
    print(token.text,token.pos_,token.dep_)
# Out:
# tesla NOUN nsubj
# is AUX aux
# n't PART neg
#   SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod

# %%
doc2
# Out:
# tesla isn't  looking into startups anymore

# %%
doc2[0]
# Out:
# tesla

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc2[0].pos_
# Out:
# 'NOUN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %%
spacy.explain('NOUN')
# Out:
# 'noun'

# %%
print(doc2[4].text)
print(doc2[4].lemma_)
# Out:
# looking
# look

# %%
print(doc2[4].pos_)
print(doc2[4].tag_+ ' / ' + spacy.explain(doc2[4].tag_))
# Out:
# VERB
# VBG / verb, gerund or present participle

# %%
print(doc2[0].text+': '+doc2[0].shape_)
print(doc2[5].text+' : '+doc[5].shape_)
# Out:
# tesla: xxxx
# into : x

# %%
print(doc2[0].is_alpha)
print(doc2[0].is_stop)
# Out:
# True
# False

# %%
doc3=nlp(u'although commonly attributed to john lennon from his song "beutiful boy", \ the phrase "life is what happens to us while we are making other plans"was written by \ cartoonist Allen Saunders and published in reader\'s digest in 1957,when lennon was 17.')

# %%
life_quote = doc3[16:30]
print(life_quote)
# Out:
# phrase "life is what happens to us while we are making other plans"was

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
doc4 = nlp(u'this is the first sentence.this is another sentence.this is last sentence.')

# %%
for sent in doc4.sents:
    print(sent)
# Out:
# this is the first sentence.this is another sentence.this is last sentence.

# %%
doc4[6].is_sent_start
# Out:
# False
