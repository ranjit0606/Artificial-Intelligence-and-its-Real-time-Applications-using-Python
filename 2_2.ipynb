# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjit0606/Artificial-Intelligence-and-its-Real-time-Applications-using-Python/blob/main/2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'‘m', 'almost', 'behind', 'give', 'n‘t', 'must', 'so', 'moreover', 'hence', 'throughout', 'had', 'hers', 'least', 'others', 'he', 'within', 'everything', 'own', 'used', 'yours', '‘ve', 'former', 'next', 'somewhere', 'such', 'these', 'unless', 'that', 'anyone', 'thence', '’ve', 'nor', 'ever', 'herein', 'but', 'afterwards', 'thereafter', 'nobody', 'than', 'alone', 'being', 'is', 'thus', 'your', 'name', 'though', 'themselves', 'here', '‘re', 'either', '’s', 'just', 'who', 'else', 'been', 'beside', 'and', "'ve", 'whatever', 'further', 'fifteen', 'yourself', 'have', 'towards', 'therefore', 'bottom', 'anyway', 'once', 'three', 'everywhere', 'at', 'several', 'via', 'would', '‘ll', 'herself', "n't", 'most', 'since', 'during', 'their', 'back', 'whence', 'well', 'its', 'it', 'to', '‘d', 'those', 'many', 'besides', 'whose', 'of', "'m", 'an', 'wherever', 'keep', 'get', 'twelve', 'seems', 'otherwise', 'often', 'again', 'make', 'onto', 'above', 'how', 'regarding', 'always', 'his', 'him', 'another', 'put', 'as', 'same', 'too', 'part', 'whom', 'sometimes', 'anything', 'because', 'them', 'none', 'became', 'everyone', 'yet', 'go', 'elsewhere', 'hereupon', 'for', 'am', 'empty', 'himself', 'becomes', 'all', 'never', 'they', 'amount', 'latter', 'seem', 'n’t', 'whereupon', 'by', 'latterly', 'in', "'d", 'between', 'please', 'ten', 'ours', 'serious', '‘s', 'neither', 'until', 'whereas', 'side', '’d', 'still', 'out', 'does', 'nevertheless', 'front', 'seeming', 'someone', 'whither', 'last', 'she', 'has', 'indeed', 'sixty', 'hundred', 'any', 'was', 'enough', 'ourselves', 'where', 'five', 'more', 'against', 'much', 'various', 'if', 'quite', 'take', 'whereby', 'less', 'beyond', 'each', 'among', 'no', 'without', 'could', 'whenever', 'twenty', 'itself', 'few', 'already', 'over', 'together', 'doing', 'thereupon', 'beforehand', 'four', 'my', 'every', 'us', "'re", 'formerly', 'also', 'while', 'along', 'a', 'somehow', 'with', 'become', 'not', 'yourselves', 'third', 'or', 'therein', 'move', 'do', 'cannot', 'six', 'really', 'nine', 'two', 'whereafter', 'what', 'now', 'although', 'before', 'can', 'eleven', 'might', 'hereafter', "'ll", 'this', 'whoever', 'did', 'around', 'done', 'hereby', 'there', 'down', 'myself', 'sometime', 'rather', 'should', 'meanwhile', 'something', 'from', 'about', 'first', 'wherein', '’ll', 'fifty', 'except', 'say', 'you', '’re', 'nowhere', 'amongst', 'after', 'i', 'were', 'anywhere', 'on', 'her', 'the', 'are', 'our', 're', 'both', 'noone', 'may', 'top', 'only', 'one', 'why', 'be', 'nothing', 'mostly', 'into', 'when', 'whole', "'s", 'through', 'toward', 'perhaps', 'even', 'made', 'we', 'off', 'using', 'namely', 'mine', 'which', 'upon', 'across', 'then', 'call', 'becoming', 'ca', 'forty', 'thereby', 'however', 'per', 'me', 'eight', 'under', 'up', 'other', 'anyhow', 'will', 'whether', 'show', 'seemed', 'some', 'below', '’m', 'thru', 'see', 'due', 'full', 'very'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mysterybox'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'‘m', 'almost', 'behind', 'give', 'n‘t', 'must', 'so', 'moreover', 'hence', 'throughout', 'had', 'hers', 'least', 'others', 'he', 'within', 'everything', 'own', 'used', 'yours', '‘ve', 'former', 'next', 'somewhere', 'such', 'these', 'unless', 'that', 'anyone', 'thence', '’ve', 'nor', 'ever', 'herein', 'but', 'afterwards', 'thereafter', 'nobody', 'than', 'alone', 'being', 'is', 'thus', 'your', 'name', 'though', 'themselves', 'here', '‘re', 'either', '’s', 'just', 'who', 'else', 'been', 'beside', 'and', "'ve", 'whatever', 'further', 'fifteen', 'yourself', 'have', 'towards', 'therefore', 'bottom', 'anyway', 'once', 'three', 'everywhere', 'at', 'several', 'via', 'would', '‘ll', 'herself', "n't", 'most', 'since', 'during', 'their', 'back', 'whence', 'well', 'its', 'it', 'to', '‘d', 'those', 'many', 'besides', 'whose', 'of', "'m", 'an', 'wherever', 'keep', 'get', 'twelve', 'seems', 'otherwise', 'often', 'again', 'make', 'onto', 'above', 'how', 'regarding', 'always', 'his', 'him', 'another', 'put', 'as', 'same', 'too', 'part', 'whom', 'sometimes', 'anything', 'because', 'them', 'none', 'became', 'everyone', 'yet', 'go', 'elsewhere', 'hereupon', 'for', 'am', 'empty', 'himself', 'becomes', 'all', 'never', 'they', 'amount', 'latter', 'seem', 'n’t', 'whereupon', 'by', 'latterly', 'in', "'d", 'between', 'please', 'ten', 'ours', 'serious', '‘s', 'neither', 'until', 'whereas', 'side', '’d', 'still', 'out', 'does', 'nevertheless', 'front', 'seeming', 'someone', 'whither', 'last', 'she', 'has', 'indeed', 'sixty', 'hundred', 'any', 'was', 'enough', 'ourselves', 'where', 'five', 'more', 'against', 'much', 'various', 'if', 'quite', 'take', 'whereby', 'less', 'beyond', 'each', 'among', 'no', 'without', 'could', 'whenever', 'twenty', 'itself', 'few', 'already', 'over', 'together', 'doing', 'thereupon', 'beforehand', 'four', 'my', 'every', 'us', "'re", 'formerly', 'also', 'while', 'along', 'a', 'somehow', 'with', 'become', 'not', 'yourselves', 'third', 'or', 'therein', 'move', 'do', 'cannot', 'six', 'really', 'nine', 'two', 'whereafter', 'what', 'now', 'although', 'before', 'can', 'eleven', 'might', 'hereafter', "'ll", 'this', 'whoever', 'did', 'around', 'done', 'hereby', 'there', 'down', 'myself', 'sometime', 'btw', 'rather', 'should', 'meanwhile', 'something', 'from', 'about', 'first', 'wherein', '’ll', 'fifty', 'except', 'say', 'you', '’re', 'nowhere', 'amongst', 'after', 'i', 'were', 'anywhere', 'on', 'her', 'the', 'are', 'our', 're', 'both', 'noone', 'may', 'top', 'only', 'one', 'why', 'be', 'nothing', 'mostly', 'into', 'when', 'whole', "'s", 'through', 'toward', 'perhaps', 'even', 'made', 'we', 'off', 'using', 'namely', 'mine', 'which', 'upon', 'across', 'then', 'call', 'becoming', 'ca', 'forty', 'thereby', 'however', 'per', 'me', 'eight', 'under', 'up', 'other', 'anyhow', 'will', 'whether', 'show', 'seemed', 'some', 'below', '’m', 'thru', 'see', 'due', 'full', 'very'}
